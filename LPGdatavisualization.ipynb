# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b4fc1419-ace4-424b-8c18-72a5b3ce570c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b4fc1419-ace4-424b-8c18-72a5b3ce570c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Table-2020_18.csv to Table-2020_18.csv

# %%
ds = pd.read_csv('Table-2020_18.csv')
ds.head()
# Out:
#   Region             State  IOCL  HPCL  BPCL  Total2020  Total2019
# 0  North        Chandigarh    18     5     4         27         27
# 1  North             Delhi   195    48    79        322        323
# 2  North           Haryana   293   138   190        621        614
# 3  North  Himachal Pradesh   145    33    25        203        196
# 4  North   Jammu & Kashmir   140   109    38        287        282

# %%
ds1 = ds.groupby(['Region'], as_index = False).sum()
ds1
# Out:
#        Region  IOCL  HPCL  BPCL  Total2020  Total2019
# 0        East  2518  1242  1106       4866       4484
# 1       North  4331  1788  1992       8111       7984
# 2  North-East   858    65   118       1041        997
# 3       South  2597  1414  1387       5398       5204
# 4        West  2146  1601  1507       5254       5068

# %%
cars = ds1['']
  
data = [23, 17, 35, 29, 12, 41]
  
  
# Creating explode data
explode = (0.1, 0.0, 0.2, 0.3, 0.0, 0.0)
  
# Creating color parameters
colors = ( "orange", "cyan", "brown",
          "grey", "indigo", "beige")
  
# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "green" }
  
# Creating autocpt arguments
def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)
  
# Creating plot
fig, ax = plt.subplots(figsize =(10, 7))
wedges, texts, autotexts = ax.pie(data, 
                                  autopct = lambda pct: func(pct, data),
                                  explode = explode, 
                                  labels = cars,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="magenta"))
  
# Adding legend
ax.legend(wedges, cars,
          title ="Cars",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))
  
plt.setp(autotexts, size = 8, weight ="bold")
ax.set_title("Customizing pie chart")
  
# show plot
plt.show()

# %%
x_axis = ds1['Region']
y_axis = ds1['Total2020']
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(x_axis, y_axis, color ='blue',width = 0.4)
 
plt.xlabel("Regions in India")
plt.ylabel("Number of LPG Customers")
plt.title("Bar Graph of Regionwise LPG Customers in India")
plt.show()

x_axis = ds1['Region']
y_axis = ds1['Total2020']
explode = (0, 0.1, 0, 0, 0)

fig1, ax1 = plt.subplots()
ax1.pie(y_axis, explode=explode, labels=x_axis, autopct='%1.1f%%',shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
fig, ax = plt.subplots(figsize =(10, 7))
wedges, texts, autotexts = ax.pie(ds['IOCL'].unique(),autopct = '%.2f%%',radius=1.2)
ax.legend(wedges, ds['Region'].unique(),loc ="center left",bbox_to_anchor =(1, 0, 0.5, 1))
ax.set_title("Pie Chart",fontweight = 'bold',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Pie Chart')
